# %%
import pandas as pd
data = [1,2,3,4,5]
series = pd.Series(data)
print("Series: \n", series)
print(type(series))
# Out:
# Series:
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.Series'>

# %%
data = {'a':1,'b':2,'c':3}
series_dict = pd.Series(data)
print(series_dict)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data = [10,20,30]
index = ['a','b','c']
pd.Series(data,index=index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
data = {
    'Name': ['Daksh','Dinkle','Rohan','Krish'],
    'Age': [19, 19, 20, 18],
    'City': ['Banglore','Banglore','New York','Florida']
}
df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#      Name  Age      City
# 0   Daksh   19  Banglore
# 1  Dinkle   19  Banglore
# 2   Rohan   20  New York
# 3   Krish   18   Florida
# <class 'pandas.DataFrame'>

# %%
data = [
    {'Name': 'Daksh', 'Age': 19, 'City': 'Banglore'},
    {'Name': 'Dinkle', 'Age': 19, 'City': 'Banglore'},
    {'Name': 'Krish', 'Age': 20, 'City': 'Florida'}
]
df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age      City
# 0   Daksh   19  Banglore
# 1  Dinkle   19  Banglore
# 2   Krish   20   Florida

# %%
data = [
    {'Name': 'Daksh', 'Age': 19, 'City': 'Banglore'},
    {'Name': 'Dinkle', 'Age': 19, 'City': 'Banglore'},
    {'Name': 'Krish', 'Age': 20, 'City': 'Florida'}
]
df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age      City
# 0   Daksh   19  Banglore
# 1  Dinkle   19  Banglore
# 2   Krish   20   Florida

# %%
df
# Out:
#      Name  Age      City
# 0   Daksh   19  Banglore
# 1  Dinkle   19  Banglore
# 2   Krish   20   Florida

# %%
df['Name']
# Out:
# 0     Daksh
# 1    Dinkle
# 2     Krish
# Name: Name, dtype: str

# %%
df.loc[0]
# Out:
# Name       Daksh
# Age           19
# City    Banglore
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# Name       Daksh
# Age           19
# City    Banglore
# Name: 0, dtype: object

# %%
print(df.at[1,'Age'])
# Out:
# 19

# %%
df['salary'] = [50000,60000,70000]

# %%
df
# Out:
#      Name  Age      City  salary
# 0   Daksh   19  Banglore   50000
# 1  Dinkle   19  Banglore   60000
# 2   Krish   20   Florida   70000

# %%
df.drop('Name',axis=1,inplace=True)

# %%
df['Age'] = df['Age']+1
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ADMIN\OneDrive\Desktop\ML\venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df['Age'] = df['Age']+1
# ...
